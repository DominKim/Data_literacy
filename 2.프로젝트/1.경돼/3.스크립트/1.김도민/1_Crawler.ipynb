# %%
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.common.by import By
from selenium.common.exceptions import ElementNotVisibleException
from selenium.webdriver import Chrome
from selenium.webdriver.common.keys import Keys
import time
from pandas.io import sql
import os
import pandas as pd
# from decouple import config
import pandas as pd
import numpy as np
from urllib.request import urlretrieve
from PIL import Image
from matplotlib import cm
import re
import requests # 웹 페이지 소스를 얻기 위한 패키지(기본 내장 패키지이다.)
from bs4 import BeautifulSoup # 웹 페이지 소스를 얻기 위한 패키지, 더 간단히 얻을 수 있다는 장점이 있다고 한다.
from datetime import datetime 

from selenium import webdriver
from tqdm import tqdm
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized"); # chrome 브라우저를 최대한 크기로 옵션을 주는 것

# Chrome 실행
browser = webdriver.Chrome('./chromedriver', options=options)

# %%
# 경돼 유튜브 이동
browser.get("https://www.youtube.com/channel/UCFa0g-8D8hYuHvdIh6XQCOg")

# 동영상탭 클릭
browser.find_element_by_xpath('//*[@id="tabsContent"]/tp-yt-paper-tab[2]/div').click()

# # 스크롤 다운
# body = browser.find_element_by_css_selector('body')
# for i in range(32):
#     body.send_keys(Keys.PAGE_DOWN)
#     time.sleep(1)

# %%
youtube_dict = {"제목":[], "조회수":[], 
                "영상_게시날짜":[], "좋아요":[], 
                "싫어요":[], "개요":[], "태그":[],
                "영상길이":[],"댓글수":[],"댓글":[]}

# 영상은 총 596개
# 제목, 해시태그, 조회수, 영상 게시날짜, 좋아요, 싫어요, 개요란, 영상길이, 댓글수, 댓글
for i in tqdm(range(1, 596)):
    # 영상 클릭
    browser.find_element_by_xpath(f'/html/body/ytd-app/div/ytd-page-manager/ytd-browse/ytd-two-column-browse-results-renderer/div[1]/ytd-section-list-renderer/div[2]/ytd-item-section-renderer/div[3]/ytd-grid-renderer/div[1]/ytd-grid-video-renderer[{str(i)}]/div[1]/div[1]/div[1]/h3/a').click()
    
    # 광고 시간 
    time.sleep(10)
    
    # 영상 멈추기
    browser.find_element_by_xpath('//*[@id="movie_player"]/div[1]/video').click()
    
    # 영상 제목
    name = browser.find_element_by_xpath('//*[@id="container"]/h1/yt-formatted-string').text
    youtube_dict["제목"].append(name)
    time.sleep(1)
    
    # 조회수
    watch = browser.find_element_by_xpath('//*[@id="count"]/ytd-video-view-count-renderer/span[1]').text
    watch = int("".join(re.findall("[0-9]{1,}",watch)))
    youtube_dict["조회수"].append(watch)
    time.sleep(1)
    
    # 영상 게시일
    day = browser.find_element_by_xpath('//*[@id="date"]/yt-formatted-string').text
    day = day.replace(" ", "")[:-1]
    youtube_dict["영상_게시날짜"].append(day)
    time.sleep(1)
    
    # page_source
    # 좋아요 수와 싫어요 수를 가져오기 위해 사용
    html0 = browser.page_source
    html = BeautifulSoup(html0,'html.parser')

    # 좋아요 수
    # 좋아요 막아 놓은 곳이 있어 try문 사용
    try:
        good = html.find('yt-formatted-string',{'id':'text','class':'style-scope ytd-toggle-button-renderer style-text','aria-label':re.compile('좋아요')}).text
        good = int(good)
        youtube_dict["좋아요"].append(good)
    except:
        youtube_dict["좋아요"].append("")
    time.sleep(1)

    # 싫어요 수
    # 싫어요 막아 놓은 곳이 있어 try문 사용
    try:
        hate = html.find('yt-formatted-string',{'id':'text','class':'style-scope ytd-toggle-button-renderer style-text','aria-label':re.compile('싫어요')}).text
        hate = int(hate)
        youtube_dict["싫어요"].append(hate)
    except:
        youtube_dict["싫어요"].append("")
    
    time.sleep(1)
    
    # 개요
    outline_test = html.find("yt-formatted-string", {"class":"content style-scope ytd-video-secondary-info-renderer"}).text    
    # hash_tag가 안달려있는 영상이 있기때문에 오류 방지
    try:
        hash_tag = " ".join(re.findall("#[가-힣]{1,}", outline_test))
        youtube_dict["태그"].append(hash_tag)
    except Exception as e:
        youtube_dict["태그"].append("")
        
    
    if hash_tag:
        try:
            outline = outline_test.replace(hash_tag, "")
            youtube_dict["개요"].append(outline)
        except:
            youtube_dict["개요"].append("")
    else:
        try:
            youtube_dict["개요"].append(outline_test)
        except:
            youtube_dict["개요"].append("")
    time.sleep(1)
    
    # 영상길이
    video_length = html.find("span", {"class":"ytp-time-duration"}).text
    youtube_dict["영상길이"].append(video_length)
    time.sleep(1)
    
    
    # 스크롤
    # 세로로 긴 영상 때문에 필요
    body = browser.find_element_by_css_selector('body')
    for i in range(3):
        body.send_keys(Keys.PAGE_DOWN)
        time.sleep(1)
    html0 = browser.page_source
    html = BeautifulSoup(html0,'html.parser')
    
    # 댓글 수
    try:
        comment_num = html.find('yt-formatted-string', {"class":"count-text style-scope ytd-comments-header-renderer"}).text
        comment_num = int(re.findall("[0-9]{1,}", comment_num)[0])
        youtube_dict["댓글수"].append(comment_num)
    except:
        youtube_dict["댓글수"].append("")
    time.sleep(1)
    
        
    # 댓글 lst
    comment_lst = []
    # 1부터
    try:
        comments = html.findAll('yt-formatted-string', {"id":"content-text", "class":"style-scope ytd-comment-renderer"})
        for i in comments:
            comment = i.text
            comment_lst.append(comment)
    except:
        comment_lst.append("")
            
    comment_lst = "\z".join(comment_lst)
    youtube_dict["댓글"].append(comment_lst)

    browser.get('https://www.youtube.com/channel/UCFa0g-8D8hYuHvdIh6XQCOg/videos')
    
    
#     return name, watch, day, good, hate, video_length, comment_num, comment_lst

# %%
pd.DataFrame(youtube_dict)
# Out:
#                                                제목    조회수    영상_게시날짜  좋아요 싫어요  \
# 0                                출근 전 벤치프레스 100kg   1507  2021.5.27   26   3
# 1                           궁금했던 것 물어보면 딱 좋은 타이밍!   1852  2021.5.14   64   2
# 2                          비아냥 속에서도 묵묵히 최선을 다할 것.   5347  2021.4.25  126   6
# 3                    78kg, 썸머슈레딩(다이어트) 시작, 이건 못참지   4393  2021.3.13   99   1
# 4                                   아침 저녁으로 운동하기!   2787   2021.3.7   74   2
# 5                        (경돼 유도) 주말에 유도 한판, 청림유도관   2085   2021.3.7   39   0
# 6                                    출퇴근 길은 헬스장으로   3563   2021.3.1   89   1
# 7                              천천히 운동 쌓아 나가기│브이로그   3563  2021.2.21   90   3
# 8                 (체중78kg) 퇴근 후 벤치프레스 100kg, 아슬아슬   4725  2021.2.21   49   0
# 9                          3개월 만에 찾은 헬스장, 회사원VLOG   3209  2021.2.12  106   5
# 10                          2021 직장인 운동브이로그(VLOG)   3530  2021.1.24  133  12
# 11                        3대500 vs 날계란 영혼의 맞다이...   2653  2021.1.12  124   2
# 12                                   오랜만에 인사드립니다!   5871  2021.1.10  301  15
# 13                  5x8x10 홈트레이닝(마이프로틴 대란 안내 9/9)   4515   2020.9.8   61  18
# 14  직장인 다이어트, 하루하루 쌓다보니 -12kg....│2020 썸머슈레딩 Ep06   8411  2020.8.22
# 15               다이어트 중 교촌 먹어 버리기│2020 썸머슈레딩 Ep05   4112  2020.8.17   90  19
# 16   돼지고기가 성실히 운동하니까 변화가 생기기 시작했다│2020 썸머슈레딩 Ep04   3801  2020.8.14   89  14
# 17             체중이 계속 빠지는 운동 VLOG│2020 썸머슈레딩 Ep03   4161  2020.8.13   90   9
# 18    돌아온 내추럴의 시대, 찐추럴이 가져야 할 자세(운동에 삶을 갉아먹히지 말자)   5571   2020.8.8  153  13
# 19               9kg 감량후 그 첫 이야기(2020 썸머슈레딩 Ep02)   3861   2020.8.7   87   7
# 20          안 맞던 옷이 맞기 시작했다(어깨운동)│2020 썸머슈레딩 Ep01   5780   2020.8.1  106   6
# 21                    저도 대회 준비 할 수 있을까요?(경돼 피지크?)   9386  2020.7.27  193  12
# 22                    회사다니면서 55일 동안 다이어트(-9kg 감량)  59482  2020.7.25  316   9
# 23                다음을 준비하는 중(feat. 구독자, 마이프로틴 대란)   4046   2020.7.5  119  11
# 24          다시 여행갈 수 있을까!? 일본 고베 브이로그2편(마이프로틴 대란)   3291   2020.6.6   73  15
# 25                        나의 동료, 주말 일상 브이로그(VLOG)   4078   2020.6.1  121  12
# 26                    쉬어가는 직장인 브이로그(feat. 대박이, 쏙)   2976  2020.5.25  102   5
# 27             고독한리프터 개발자를 만나다(운동 VLOG/ 마이프로틴 할인)   4650   2020.5.4   98   9
# 28                  지피티 보고있나! 퇴근 후 100kg 벤치프레스 도전   6600  2020.4.23  107   8
# 29            같은 하루도 가치있게 보내기 위해 노력하기│오픽 점수, 구전녹용   5140  2020.4.18  123  15
#
#                                                    개요                   태그  \
# 0
# 1   여러분 안녕하세요 경돼입니다.\n\n모두\n\nBe more positive!\n\...
# 2                                         벚꽃슈레딩 Day25
# 3                                             또머슈레딩\n    #썸머슈레딩 #다이어트 #직장인
# 4   여러분 안녕하세요 경돼입니다.\n\n이제 운동을, 하루에 2번씩 넣어주고 있습니다....
# 5                                               주말 유도
# 6   여러분 안녕하세요 경돼입니다.\n\n\n\n----------------------...
# 7   여러분 안녕하세요 경돼입니다.\n\n\n\n----------------------...
# 8   여러분 안녕하세요 경돼입니다.\n\n\n\n----------------------...
# 9   여러분 안녕하세요 경돼입니다.\n\n즐거운 설 연휴 보내세요!\n\nBe more ...
# 10  여러분 안녕하세요 경돼입니다.\n\n\n\n----------------------...
# 11  여러분 안녕하세요 경돼입니다.\n\n\n하하........\n\n\n\n발렸다......
# 12  여러분 안녕하세요 경돼입니다.\n\n오랜만에 인사 드리네요.\n\n모두 새해복 많이...
# 13  여러분 안녕하세요 경돼입니다.\n\n집에서 운동하는 날이 많아지면서.... 저도 홈...
# 14  여러분 안녕하세요 경돼입니다.\n\n\n\n----------------------...
# 15  여러분 안녕하세요 경돼입니다.\n\n영상 속에서 제가 소개한 운동 모티베이션 영상은...
# 16  #2020썸머슈레딩 \n\n여러분 안녕하세요 경돼입니다.\n\n대한득근만세, 광복절...       #다이어트 #직장인브이로그
# 17  #2020썸머슈레딩 \n여러분 안녕하세요 경돼입니다.\n\n썸머슈레딩 에피소드 3편...           #다이어트 #칼로리
# 18   \n여러분 안녕하세요 경돼입니다.\n\n운동에 삶을 갉아먹히지 말자\n\n\n\n...         #돌아온내추럴 #내추럴
# 19  여러분 안녕하세요 경돼입니다.\n\n\n8/8대란에 맞춰 마이프로틴 행사 안내 드립...
# 20  여러분 안녕하세요 경돼입니다.\n\n드디어 시작된 썸머슈레딩 에피소드... 이번에는...
# 21  \n여러분 안녕하세요 경돼입니다.\n\n신선한 충격으로 다가올 이번 영상.....\...      #경돼 #대회준비 #중대발표
# 22  \n\n여러분 안녕하세요 경돼입니다.\n\n\n55일간의 다이어트를 마쳤습니다.\n...  #썸머슈레딩 #다이어트 #비포애프터
# 23  여러분 안녕하세요 경돼입니다.\n\n다음을 준비한다면 과연 무엇일까요?!\n\n\n...
# 24  여러분 안녕하세요 경돼입니다.\n\n드디어 편집을 마친 고베 브이로그 2편....\...
# 25  여러분 안녕하세요 경돼입니다.\n\n새로운 한주도 화이팅 하시기를...!\n\n\n...
# 26  여러분 안녕하세요 경돼입니다.\n\n3월에 찍어 둔 영상 몇가지로 근황을 전합니다 ...
# 27  여러분 안녕하세요 경돼입니다.\n\n오늘은 고독한 리프터 개발자 김주용님을 만나서 ...
# 28   #100kg \n\n지피티님 영상 보고 퇴근 후 도전해보았습니다 ㅎㅎ\n\n\n닭...          #지피티 #벤치프레스
# 29  여러분 안녕하세요 경돼입니다.\n\n2020년 3월의 VLOG 영상입니다.\n\n\...
#
#      영상길이  댓글수                                                 댓글
# 0    0:41   13  아니 100키로 몇번을 하는거야 ㄷㄷㄷ\z20kg바 맞아여? 출근전 운동진짜..리스...
# 1    0:06   17  진짜 대박이까지만 보고 껐습니다 죄송합니다\z경돼님 다른건 몰라도 정직 ,근면  ,...
# 2    0:12   63  경돼형 구독한지 대략3년..드디어 슈레딩 성공을 보다니..\z취준생 시절에 보기 시...
# 3    0:30   53  내게 경돼의 썸머 슈뤠딩이란... \n나 93년 국민학교 여름방학 일기장 항상 못써...
# 4    6:58   41  3:01 구독자 감소 point\z와 몸 또 만들었네요.. 대박~ 멋있어요\z여친 ...
# 5    1:23   15  경돼형 유투브 다시 시작했구나!!!!!\z경돼님 유도영상 너무 좋아요\z설킴이 응원...
# 6    8:47   43  경돼 영상으로 주말 마무리 하는거 찐소확행\z같은 동네 살아서 배경이 친근하네요\n...
# 7    0:30   37  경돼형님 벌써 4년가까이 구독중인데 항상 영상재밌게 보구있습니다 ㅋㅋ\n운동도 그렇...
# 8    0:34   21  크 경돼님 추억이네. 군대 전역하고 대학교 3학년 때 처음 경돼랑 운지기 보면서 이...
# 9   17:21   35  그저 평범한 사회의 한 구성원으로서 \n가장 현실적인 모습을 보여주는 \n이시대 최...
# 10  11:31   45  3:31 ㅋㄱㅋㄱㅋㄱㅋㄱㅋㄱㅋㄱㅋㄱㅋㄱㅋㄱㅋㄱㅋㄱㅋㄱㅋ형 훅들어와서 놀랬어\z귀여워...
# 11   2:29   44  경돼형 다시 돌아와서 좋다\n근데 손가락에 못보던게 있는데 내가 잘못본거 맞지?\n...
# 12   0:15  144  와아 댓글들 정말 감사합니다...!\n앞으로 느리더라도 꾸준히 영상 업로드 할게요....
# 13  23:59   49  형 언제와 보고싶어\z집에서 헬스장급으로 땀 흘렸슴다.. 개꿀\z경돼 화이팅!\z빨...
# 14   9:44
# 15   9:50   40  ㅋㅋ경돼형 영상은 보면 그냥 뭔가 기분이 좋음\z돌아온 교촌로이더 갓돼..\z와 남...
# 16   4:27   36  2020 썸머슈레딩은 순항 중?\n\n과연 성공할 수 있을까?!!\n\n대한득근만세...
# 17   0:34   41  저것이 벤치100kg 18방의 갑빠인가...ㄷㄷ\z와 진짜 워너비몸 ㄹㅇ ㅠㅠㅠㅠㅠ...
# 18   4:39   44  대회준비 화이팅입니닷👍\z경돼님 ❤️❤️ 필승!!!\z오늘  80년대 화질같아요.\...
# 19   7:58   44  어느 여자 마음을 훔치려고..\z다음 영상 재밌게 다이어트하는 비법 영상 업로드 예...
# 20  11:52   50  익숙하지않다,,, 썸슈는 실패해야 제맛인데\z대학생때로 돌아가는건가요 형님!!ㅋㅋ ...
# 21   7:03   95  쫙 말린 경돼 형 보고 싶어요ㅠㅠ 운동 인생 전환점이 되실듯!\z가슴근육이 존나멋짐...
# 22   0:30   92  경돼야ㅠㅠㅠ\n리플은 많이 안달았지만 오랫동안 봐온 구독자로서 88까지 찍었다니 맘...
# 23  10:14   76  8:39 벤치프레스 140kg 보조 없이.. .실화?!!!!!\n\n마이프로틴 대란...
# 24  16:30   36  마지막에 한국으로 돌아갈때 저도 아쉬워지는 느낌.. ㅠ 일본시리즈 넘 좋네요 ㅎㅎㅎ...
# 25   5:57   35  경돼형  바쁘더라도 계속 올려줘요ㅠㅠ\z5:30 경돼님 살아있나 확인하는 대박이ㅋㅋ...
# 26   5:19   32  경돼님과 같이 세월을 보내네요~~ 경돼님 대학생때부터 아주 잘 보고있어요\z이런거라...
# 27   7:08   31  안녕하세요 경돼입니다!\n마이프로틴 할인 진행 중입니다 아래 링크로 할인 받고 구입...
# 28   0:29   41  아....... 진짜 정말 강하네... 직장인 최강자인가..\n코리안 에버리지 가이...
# 29  12:17   26  경돼형 요즘 유튜브 열일하네? 응원할께! 파이팅!\z말할 때 제스쳐가 거의 뭐 한국...

# %% [markdown]
# - 댓글수 : html로 받기
# - 태그도 오류 예외문 작성 필요
# - 광고 고려 필요
#     - 광고 길이가 긴 영상들이 있음
